# %%
# ============================================
# Experiment: Baseline Model
# Date: 2025-10-03
# Goal: Establish baseline performance
# Hypothesis: Simple linear model will achieve >80% accuracy
# ============================================

# %% [markdown]
# # %% [markdown]
# # ## Setup
# # - Dataset: v1.2 (500 samples)
# # - Model: Logistic Regression
# # - Evaluation: 5-fold CV
# # - Random seed: 42

# %%
# %% Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
# ... more imports

# %%
# %% Configuration
CONFIG = {
    'data_path': '../data/processed/dataset_v1.2.csv',
    'random_seed': 42,
    'test_size': 0.2,
    'model_params': {'C': 1.0, 'max_iter': 1000}
}

# %% [markdown]
# # %% [markdown]
# # ## Load Data

# %%
# %% Load and inspect
data = pd.load_csv(CONFIG['data_path'])
print(f"Data shape: {data.shape}")
data.head()

# %% [markdown]
# # %% [markdown]
# # ## Results
# #
# # **Accuracy**: 87.3% (±2.1%)
# #
# # **Observations**:
# # - Model performs well on class A but struggles with class B
# # - Overfitting observed after epoch 15
# #
# # **Next Steps**:
# # - Try regularization (increase penalty)
# # - Collect more class B samples

# %%
# %% Save outputs
model.save('../models/baseline_v1.pkl')
fig.savefig('../results/2025-10-03_baseline/confusion_matrix.png')
